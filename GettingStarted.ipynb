# %%
import os
from dotenv import load_dotenv
load_dotenv()

os.environ["OPENAI_API_KEY"] = os.getenv("OPENAI_API_KEY")
os.environ["LANGCHAIN_API_KEY"] = os.getenv("LANGCHAIN_API_KEY")
os.environ["LANGCHAIN_TRACING_V2"] = "true"
os.environ["LANGCHAIN_PROJECT"]=os.getenv("LANGCHAIN_PROJECT")

# %%
# !pip install ipykernel

# %%
# from langchain_openai import ChatOpenAI

# llm = ChatOpenAI()
# print(llm)

# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(model="gpt-4o")
print(llm)
# Out:
# client=<openai.resources.chat.completions.completions.Completions object at 0x000001BB7ED8BB30> async_client=<openai.resources.chat.completions.completions.AsyncCompletions object at 0x000001BB7EDCDB20> root_client=<openai.OpenAI object at 0x000001BB7EDF2F00> root_async_client=<openai.AsyncOpenAI object at 0x000001BB7EDF2AB0> model_name='gpt-4o' model_kwargs={} openai_api_key=SecretStr('**********')

# %%
result =llm.invoke("What is generative AI?")

# %%
print(result)
# Out:
# content='Generative AI refers to a branch of artificial intelligence that focuses on creating systems capable of generating content that is similar to what might be produced by humans. This involves using algorithms and models to create new data instances that resemble the existing data it was trained on. Some common applications of generative AI include:\n\n1. **Text Generation**: Producing human-like text based on input prompts, as seen with models like GPT-3 and GPT-4.\n\n2. **Image Generation**: Creating realistic images or artwork from text descriptions or other inputs, examples include DALL-E and Stable Diffusion.\n\n3. **Audio and Music Creation**: Composing music or generating speech that mimics human voice characteristics.\n\n4. **Video Generation**: Synthesizing new video content, or modifying existing videos to include altered or entirely new scenes.\n\n5. **Data Augmentation**: Generating additional training examples to improve machine learning models, especially when data is limited.\n\nGenerative AI techniques often use deep learning models like Generative Adversarial Networks (GANs) and Variational Autoencoders (VAEs) to produce these outputs. These models learn patterns in the input data and use those patterns to create plausible variations. The goal is not just to copy existing data but to use learned patterns to generate new, original outputs.' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 265, 'prompt_tokens': 13, 'total_tokens': 278, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_f33640a400', 'id': 'chatcmpl-CDXvyXopCmfV6MXgBn4VX8k50DZwu', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='run--dbb9622a-1ce3-48c1-80d1-e971a9fec918-0' usage_metadata={'input_tokens': 13, 'output_tokens': 265, 'total_tokens': 278, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}

# %%
print(result)["content"]
# Out:
# content='Generative AI refers to a branch of artificial intelligence that focuses on creating systems capable of generating content that is similar to what might be produced by humans. This involves using algorithms and models to create new data instances that resemble the existing data it was trained on. Some common applications of generative AI include:\n\n1. **Text Generation**: Producing human-like text based on input prompts, as seen with models like GPT-3 and GPT-4.\n\n2. **Image Generation**: Creating realistic images or artwork from text descriptions or other inputs, examples include DALL-E and Stable Diffusion.\n\n3. **Audio and Music Creation**: Composing music or generating speech that mimics human voice characteristics.\n\n4. **Video Generation**: Synthesizing new video content, or modifying existing videos to include altered or entirely new scenes.\n\n5. **Data Augmentation**: Generating additional training examples to improve machine learning models, especially when data is limited.\n\nGenerative AI techniques often use deep learning models like Generative Adversarial Networks (GANs) and Variational Autoencoders (VAEs) to produce these outputs. These models learn patterns in the input data and use those patterns to create plausible variations. The goal is not just to copy existing data but to use learned patterns to generate new, original outputs.' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 265, 'prompt_tokens': 13, 'total_tokens': 278, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_f33640a400', 'id': 'chatcmpl-CDXvyXopCmfV6MXgBn4VX8k50DZwu', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='run--dbb9622a-1ce3-48c1-80d1-e971a9fec918-0' usage_metadata={'input_tokens': 13, 'output_tokens': 265, 'total_tokens': 278, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 print(result)["content"]
#
# TypeError: 'NoneType' object is not subscriptable
